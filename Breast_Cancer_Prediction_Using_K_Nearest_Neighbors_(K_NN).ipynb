# %% [markdown]
# <a href="https://colab.research.google.com/github/shakeelrifathcse/Machine-Learning-basic-Projects/blob/main/Breast_Cancer_Prediction_Using_K_Nearest_Neighbors_(K_NN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: import all essential library needed for KNN classification

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np

# %%
# prompt: view first 10 data row

df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
X = df[["radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean","radius_se","texture_se","perimeter_se","area_se","smoothness_se","compactness_se","concavity_se","concave points_se","symmetry_se","fractal_dimension_se","radius_worst","texture_worst","perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst","concave points_worst","symmetry_worst","fractal_dimension_worst"]]
y = df["diagnosis"]

# %%
# prompt: replace M and B in diagnosis to 0 and 1

df['diagnosis'] = df['diagnosis'].replace('M', 0)
df['diagnosis'] = df['diagnosis'].replace('B', 1)

# %%
df.tail(10)
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 559  925291          1        11.51         23.93           74.52      403.5
# 560  925292          1        14.05         27.15           91.38      600.4
# 561  925311          1        11.20         29.37           70.67      386.0
# 562  925622          0        15.22         30.62          103.40      716.9
# 563  926125          0        20.92         25.09          143.00     1347.0
# 564  926424          0        21.56         22.39          142.00     1479.0
# 565  926682          0        20.13         28.25          131.20     1261.0
# 566  926954          0        16.60         28.08          108.30      858.1
# 567  927241          0        20.60         29.33          140.10     1265.0
# 568   92751          1         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
train = y_train.replace(0, 'M')
y_train = y_train.replace(1, 'B')
y_test = y_test.replace(0, 'M')
y_test = y_test.replace(1, 'B')

# %%
x_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 210       20.580         22.14          134.70     1290.0          0.09090
# 509       15.460         23.95          103.80      731.3          0.11830
# 63         9.173         13.86           59.20      260.9          0.07721
# 459        9.755         28.20           61.68      290.9          0.07984
# 521       24.630         21.60          165.50     1841.0          0.10300
# ..           ...           ...             ...        ...              ...
# 164       23.270         22.04          152.10     1686.0          0.08439
# 379       11.080         18.83           73.30      361.6          0.12160
# 258       15.660         23.20          110.20      773.5          0.11090
# 384       13.280         13.72           85.79      541.8          0.08363
# 189       12.300         15.90           78.83      463.7          0.08080
#
# ...

# %%
y_train
train = y_train.replace(0, 'M')
y_train = y_train.replace(1, 'B')
y_test = y_test.replace(0, 'M')
y_test = y_test.replace(1, 'B')

# %%
# prompt: replace y value 0 and 1

y_train
# Out:
# 175    B
# 232    B
# 109    B
# 298    B
# 6      M
#       ..
# 467    B
# 91     M
# 174    B
# 307    B
# 314    B
# Name: diagnosis, Length: 455, dtype: object

# %%
knn = KNeighborsClassifier(n_neighbors=2)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8859649122807017

# %%
# prompt: Now the KNN model is created, Now I need to predict the Y value by inputting the X values. So provide me the code which will get user input as X values and give me the prediction as Y value 0 or 1

import numpy as np
def predict_cancer_type():
  # Get user input for X values
  radius_mean = float(input("Enter radius_mean: "))
  texture_mean = float(input("Enter texture_mean: "))
  perimeter_mean = float(input("Enter perimeter_mean: "))
  area_mean = float(input("Enter area_mean: "))
  smoothness_mean = float(input("Enter smoothness_mean: "))
  compactness_mean = float(input("Enter compactness_mean: "))
  concavity_mean = float(input("Enter concavity_mean: "))
  concave_points_mean = float(input("Enter concave points_mean: "))
  symmetry_mean = float(input("Enter symmetry_mean: "))
  fractal_dimension_mean = float(input("Enter fractal_dimension_mean: "))
  radius_se = float(input("Enter radius_se: "))
  texture_se = float(input("Enter texture_se: "))
  perimeter_se = float(input("Enter perimeter_se: "))
  area_se = float(input("Enter area_se: "))
  smoothness_se = float(input("Enter smoothness_se: "))
  compactness_se = float(input("Enter compactness_se: "))
  concavity_se = float(input("Enter concavity_se: "))
  concave_points_se = float(input("Enter concave points_se: "))
  symmetry_se = float(input("Enter symmetry_se: "))
  fractal_dimension_se = float(input("Enter fractal_dimension_se: "))
  radius_worst = float(input("Enter radius_worst: "))
  texture_worst = float(input("Enter texture_worst: "))
  perimeter_worst = float(input("Enter perimeter_worst: "))
  area_worst = float(input("Enter area_worst: "))
  smoothness_worst = float(input("Enter smoothness_worst: "))
  compactness_worst = float(input("Enter compactness_worst: "))
  concavity_worst = float(input("Enter concavity_worst: "))
  concave_points_worst = float(input("Enter concave points_worst: "))
  symmetry_worst = float(input("Enter symmetry_worst: "))
  fractal_dimension_worst = float(input("Enter fractal_dimension_worst: "))

  # Create a numpy array of the input values
  new_x = np.array([[radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave_points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave_points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave_points_worst, symmetry_worst, fractal_dimension_worst]])

  # Predict the Y value using the trained KNN model
  prediction = knn.predict(new_x)

  # Print the prediction result
  if prediction == 0:
    print("The cancer type is Malignant (M).")
  else:
    print("The cancer type is Benign (B).")

# Call the predict_cancer_type function to get the prediction
predict_cancer_type()110000
# Out:
# Enter radius_mean: 20.18
# Enter texture_mean: 3.54
# Enter perimeter_mean: 33.8
# Enter area_mean: 1250
# Enter smoothness_mean: 0.1133
# Enter compactness_mean: 0.1489
# Enter concavity_mean: 0.2133
# Enter concave points_mean: 0.1259
# Enter symmetry_mean: 0.1724
# Enter fractal_dimension_mean: 0.06053
# Enter radius_se: 0.4331
# Enter texture_se: 1.004
# Enter perimeter_se: 3.008
# Enter area_se: 52.49
# Enter smoothness_se: 0.009087
# Enter compactness_se: 0.02714
# Enter concavity_se: .05546
# Enter concave points_se: .0191
# Enter symmetry_se: .02451
# Enter fractal_dimension_se: 0.004005
# Enter radius_worst: 22.03
# Enter texture_worst: 25.07
# Enter perimeter_worst: 146
# Enter area_worst: 1479
# Enter smoothness_worst: 0.1665
# Enter compactness_worst: 0.2942
# Enter concavity_worst: 0.5308
# Enter concave points_worst: 0.2173
# Enter symmetry_worst: 0.3032
# Enter fractal_dimension_worst: .08075
# The cancer type is Benign (B).
# ...

# %% [markdown]
# ###Breast Cancer Prediction Using K-Nearest Neighbors (K-NN) The cancer type is Benign (B)
